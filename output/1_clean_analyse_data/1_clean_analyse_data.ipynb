# %%
# declare a list tasks whose products you want to use as inputsupstream = ['0_source_data']
upstream = ['0_source_data']

# %%
# Parameters
upstream = {"0_source_data": {"obesity_data": "/Users/lukastang/Documents/GitHub/Model_Interpretability/output/0_source_data/Processed_Obesity_Dataset.csv", "obesity_mappings": "/Users/lukastang/Documents/GitHub/Model_Interpretability/output/0_source_data/Obesity_Dataset_Mappings.csv", "nb": "/Users/lukastang/Documents/GitHub/Model_Interpretability/output/0_source_data/0_source_data.ipynb", "on_finish": "/Users/lukastang/Documents/GitHub/Model_Interpretability/0_source_data_test.py"}}
product = {"data": "/Users/lukastang/Documents/GitHub/Model_Interpretability/output/1_clean_analyse_data/clean_analyse_data.csv", "nb": "/Users/lukastang/Documents/GitHub/Model_Interpretability/output/1_clean_analyse_data/1_clean_analyse_data.ipynb"}

# %%
import pandas as pd
from helpers.mymodule import greeting
greeting("Me")
from helpers.variable_ordering import  set_categorical_order 
from helpers.feature_charts import FeaturePlot
#from helpers.feature_charts import ordered_class_plot
#from helpers.feature_charts import numerical_feature_plot
# Out:
# Hello, Me

# %%
obesity_dataset = pd.read_csv(upstream['0_source_data']['obesity_data'])
obesity_dataset_mappings = pd.read_csv(upstream['0_source_data']['obesity_mappings'])
# some data cleaning code...

# %%
# Set the categorical order for the specified variables
obesity_dataset = set_categorical_order(obesity_dataset, obesity_dataset_mappings)
# Filter cases where Sex_mapped is 'Male'
male_obesity_dataset = obesity_dataset[obesity_dataset['Sex_mapped'] == 'Male']
# Filter cases where Sex_mapped is 'Female'
female_obesity_dataset = obesity_dataset[obesity_dataset['Sex_mapped'] == 'Female']

# %%
# Print a summary of the dataset
print(obesity_dataset.describe(include='all'))
print(obesity_dataset.info())
# Out:
#                 Age       Height Sex_mapped Overweight_Obese_Family_mapped  \
# count   1610.000000  1610.000000       1610                           1610
# unique          NaN          NaN          2                              2
# top             NaN          NaN     Female                             No
# freq            NaN          NaN        898                           1344
# mean      33.115528   167.741615        NaN                            NaN
# std        9.835076     7.979873        NaN                            NaN
# min       18.000000   150.000000        NaN                            NaN
# 25%       25.000000   161.000000        NaN                            NaN
# 50%       32.000000   168.000000        NaN                            NaN
# 75%       41.000000   174.000000        NaN                            NaN
# max       54.000000   193.000000        NaN                            NaN
#
#        Consumption_of_Fast_Food_mapped  \
# count                             1610
# unique                               2
# top                                 No
# freq                              1174
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#        Frequency_of_Consuming_Vegetables_mapped  \
# count                                      1610
# unique                                        3
# top                                   Sometimes
# freq                                        708
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
#
#        Number_of_Main_Meals_Daily_mapped Food_Intake_Between_Meals_mapped  \
# count                               1610                             1610
# unique                                 3                                4
# top                                    3                        Sometimes
# freq                                 928                              564
# mean                                 NaN                              NaN
# std                                  NaN                              NaN
# min                                  NaN                              NaN
# 25%                                  NaN                              NaN
# 50%                                  NaN                              NaN
# 75%                                  NaN                              NaN
# max                                  NaN                              NaN
#
#        Smoking_mapped Liquid_Intake_Daily_mapped  \
# count            1610                       1610
# unique              2                          3
# top                No         More than 2 Liters
# freq             1118                        631
# mean              NaN                        NaN
# std               NaN                        NaN
# min               NaN                        NaN
# 25%               NaN                        NaN
# 50%               NaN                        NaN
# 75%               NaN                        NaN
# max               NaN                        NaN
#
#        Calculation_of_Calorie_Intake_mapped Physical_Excercise_mapped  \
# count                                  1610                      1610
# unique                                    2                         5
# top                                      No           7 days per week
# freq                                   1324                       386
# mean                                    NaN                       NaN
# std                                     NaN                       NaN
# min                                     NaN                       NaN
# 25%                                     NaN                       NaN
# 50%                                     NaN                       NaN
# 75%                                     NaN                       NaN
# max                                     NaN                       NaN
#
#        Schedule_Dedicated_to_Technology_mapped  \
# count                                     1610
# unique                                       3
# top                          3-5 hours per day
# freq                                       826
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        Type_of_Transportation_Used_mapped Class_mapped
# count                                1610         1610
# unique                                  5            4
# top                            Automobile       Normal
# freq                                  660          658
# mean                                  NaN          NaN
# std                                   NaN          NaN
# min                                   NaN          NaN
# 25%                                   NaN          NaN
# 50%                                   NaN          NaN
# 75%                                   NaN          NaN
# max                                   NaN          NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Age                                       1610 non-null   int64
#  1   Height                                    1610 non-null   int64
#  2   Sex_mapped                                1610 non-null   object
#  3   Overweight_Obese_Family_mapped            1610 non-null   object
#  4   Consumption_of_Fast_Food_mapped           1610 non-null   object
#  5   Frequency_of_Consuming_Vegetables_mapped  1610 non-null   category
#  6   Number_of_Main_Meals_Daily_mapped         1610 non-null   category
#  7   Food_Intake_Between_Meals_mapped          1610 non-null   category
#  8   Smoking_mapped                            1610 non-null   object
#  9   Liquid_Intake_Daily_mapped                1610 non-null   category
#  10  Calculation_of_Calorie_Intake_mapped      1610 non-null   object
#  11  Physical_Excercise_mapped                 1610 non-null   object
#  12  Schedule_Dedicated_to_Technology_mapped   1610 non-null   category
#  13  Type_of_Transportation_Used_mapped        1610 non-null   object
#  14  Class_mapped                              1610 non-null   category
# dtypes: category(6), int64(2), object(7)
# memory usage: 123.7+ KB
# None

# %%
# Various visualizations of the features
FeaturePlot_all = FeaturePlot(obesity_dataset)
FeaturePlot_male = FeaturePlot(male_obesity_dataset)
FeaturePlot_female = FeaturePlot(female_obesity_dataset)

# %%
# Class distribution by Sex
FeaturePlot_all.create_plot(x='Class_mapped', fill='Sex_mapped', title='Class Distribution by Sex')
# Class distribution by Age
FeaturePlot_all.create_plot(x='Age', fill='Class_mapped', title='Class Distribution by Age',plot_type='histogram')
# Class distribution by Age (Male)
FeaturePlot_male.create_plot(x='Age', fill='Class_mapped', title='Class Distribution by Age (Male)',plot_type='histogram')
# Class distribution by Age (Female)
FeaturePlot_female.create_plot(x='Age', fill='Class_mapped', title='Class Distribution by Age (Female)',plot_type='histogram')
# Out:
# /Users/lukastang/Documents/GitHub/Model_Interpretability/ploomber/lib/python3.10/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 11'. Pick better value with 'binwidth'.

# %%
FeaturePlot_all.create_plot(x='Height', fill='Class_mapped', title='Class Distribution by Height',plot_type='histogram')
# Out:
# /Users/lukastang/Documents/GitHub/Model_Interpretability/ploomber/lib/python3.10/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 20'. Pick better value with 'binwidth'.

# %%
FeaturePlot_male.create_plot(x='Height', fill='Class_mapped', title='Class Distribution by Height (Male)',plot_type='histogram')
# Out:
# /Users/lukastang/Documents/GitHub/Model_Interpretability/ploomber/lib/python3.10/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 21'. Pick better value with 'binwidth'.

# %%
FeaturePlot_female.create_plot(x='Height', fill='Class_mapped', title='Class Distribution by Height (Female)',plot_type='histogram')
# Out:
# /Users/lukastang/Documents/GitHub/Model_Interpretability/ploomber/lib/python3.10/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 23'. Pick better value with 'binwidth'.

# %%
# Save the cleaned dataset to a CSV file
obesity_dataset.to_csv('output/1_clean_analyse_data/clean_analyse_data.csv', index=False)

# %%
print("Cleaned data generated and saved to 'artificial_data.csv'")
# Out:
# Cleaned data generated and saved to 'artificial_data.csv'
